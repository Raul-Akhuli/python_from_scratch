# %%
str = 'zebronics'

# %%
# to find length.

len(str)
# Out:
# 9

# %%
# to find out whether a variable string end with a specific string or not.

str.endswith('ics')
# Out:
# True

# %%
# count the total number of occurences of any character.

str.count('i')
# Out:
# 1

# %%
# capitalize the first character of a string.

print(str.capitalize())               # this function does not change the original one.    

capitalized_string = str.capitalize()
print(capitalized_string)
str
# Out:
# Zebronics
# Zebronics
# 'zebronics'

# %%
# find a word and return the index of first occurence.

str.find('b')
# Out:
# 2

# %%
# replace the old word with the new word in the entire string.

print(str.replace('n', 'm'))  # this function does not change the original one.
str
# Out:
# zebromics
# 'zebronics'
